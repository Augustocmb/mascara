# %%
import matplotlib.pyplot as plt
import healpy as hp
import numpy as np

# %%
? hp.mollview

# %%
NSIDE = 16
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 3072

# %%
# ?np.array

# %%
# ?np.arange

# %%
# ?for
# Out:
# Object `for` not found.

# %%
#m=([0,1,1,1,0,0,0,0])

mapa = np.arange(NPIX)
for i in range(NPIX):
   if  i/2==0:
       mapa[(i)]==1
       
   else:
       mapa[(i)]==1

# %%
hp.mollview(mapa,nest =True )

# %%
lmax = 7
cl =hp.anafast(mapa(), lmax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 lmax = 7
# ----> 2 cl =hp.anafast(mapa(), lmax)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
ell = np.arange(len(cl))

# %%
plt.plot(ell, cl*(ell+1)*ell)
